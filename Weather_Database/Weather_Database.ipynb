# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies
import pandas as pd
import random
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | xiaoweizhai
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | hay river
# Processing Record 5 of Set 1 | poum
# Processing Record 6 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 1 | merauke
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | aranos
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | elhovo
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | acarau
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | alofi
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | celestun
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | alice springs
# Processing Record 25 of Set 1 | petropavlovka
# Processing Record 26 of Set 1 | tecoanapa
# Processing Record 27 of Set 1 | pittsburg
# Processing Record 28 of Set 1 | taoudenni
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | tuatapere
# Processing Record 34 of Set 1 | srednekolymsk
# Processing Record 35 of Set 1 | talcahuano
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | ratnapura
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | yinchuan
# Processing Record 43 of Set 1 | bac lieu
# Processing Record 44 of Set 1 | golpayegan
# Processing Record 45 of Set 1 | grajau
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | makurdi
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | qaqortoq
# Processing Record 2 of Set 2 | eureka
# Processing Record 3 of Set 2 | camacha
# Processing Record 4 of Set 2 | banjar
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | paranaiba
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | aviles
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | marolambo
# Processing Record 18 of Set 2 | cayenne
# Processing Record 19 of Set 2 | warrnambool
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | kokopo
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | maragogi
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | vila do maio
# Processing Record 27 of Set 2 | chipiona
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | piacabucu
# Processing Record 31 of Set 2 | monki
# Processing Record 32 of Set 2 | rikitea
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | hoa binh
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | bubaque
# Processing Record 37 of Set 2 | cururupu
# Processing Record 38 of Set 2 | samarai
# Processing Record 39 of Set 2 | port hardy
# Processing Record 40 of Set 2 | dekar
# Processing Record 41 of Set 2 | baykit
# Processing Record 42 of Set 2 | becerril
# Processing Record 43 of Set 2 | vrangel
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | stornoway
# Processing Record 48 of Set 2 | kathmandu
# Processing Record 49 of Set 2 | presidencia roque saenz pena
# Processing Record 50 of Set 2 | ust-nera
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | yerbogachen
# Processing Record 3 of Set 3 | bengkulu
# Processing Record 4 of Set 3 | erdenet
# Processing Record 5 of Set 3 | pangody
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | yulara
# Processing Record 9 of Set 3 | anadyr
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | thilogne
# City not found. Skipping...
# Processing Record 12 of Set 3 | muros
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | hasaki
# Processing Record 15 of Set 3 | anshun
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | grande prairie
# Processing Record 18 of Set 3 | nouakchott
# Processing Record 19 of Set 3 | ustye
# Processing Record 20 of Set 3 | kloulklubed
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | birao
# Processing Record 23 of Set 3 | naze
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 3 | faanui
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | pokhara
# Processing Record 29 of Set 3 | tateyama
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | san vicente
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | prachatice
# Processing Record 38 of Set 3 | ipoti
# Processing Record 39 of Set 3 | sambava
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | dhidhdhoo
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | pahrump
# Processing Record 45 of Set 3 | constitucion
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | dongsheng
# Processing Record 49 of Set 3 | xining
# Processing Record 50 of Set 3 | juneau
# Processing Record 1 of Set 4 | gdov
# Processing Record 2 of Set 4 | takahashi
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | lata
# Processing Record 6 of Set 4 | huarmey
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | tual
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 4 | puerto escondido
# Processing Record 13 of Set 4 | gaya
# Processing Record 14 of Set 4 | sitka
# Processing Record 15 of Set 4 | ulladulla
# Processing Record 16 of Set 4 | regen
# Processing Record 17 of Set 4 | buritis
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | buin
# Processing Record 20 of Set 4 | wilmington
# Processing Record 21 of Set 4 | sola
# Processing Record 22 of Set 4 | sabang
# Processing Record 23 of Set 4 | green river
# Processing Record 24 of Set 4 | kysyl-syr
# Processing Record 25 of Set 4 | banepa
# Processing Record 26 of Set 4 | mitsamiouli
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | honiara
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | uglovka
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | khipro
# Processing Record 34 of Set 4 | fort frances
# Processing Record 35 of Set 4 | momil
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | victor harbor
# Processing Record 42 of Set 4 | qena
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | mazagao
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | weligama
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | pemangkat
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | palamedu
# Processing Record 1 of Set 5 | northam
# Processing Record 2 of Set 5 | grao mogol
# Processing Record 3 of Set 5 | mariental
# Processing Record 4 of Set 5 | nenjiang
# Processing Record 5 of Set 5 | am timan
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | borlange
# City not found. Skipping...
# Processing Record 8 of Set 5 | mogadishu
# Processing Record 9 of Set 5 | tangua
# Processing Record 10 of Set 5 | mumbwa
# Processing Record 11 of Set 5 | lavrentiya
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | manta
# Processing Record 14 of Set 5 | hauterive
# Processing Record 15 of Set 5 | brigantine
# Processing Record 16 of Set 5 | roma
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | wyoming
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | olavarria
# Processing Record 22 of Set 5 | lahij
# Processing Record 23 of Set 5 | nalut
# Processing Record 24 of Set 5 | cancun
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | sobolevo
# Processing Record 27 of Set 5 | denpasar
# Processing Record 28 of Set 5 | dafeng
# Processing Record 29 of Set 5 | kyren
# Processing Record 30 of Set 5 | karaton
# Processing Record 31 of Set 5 | pokrovsk
# Processing Record 32 of Set 5 | chulman
# Processing Record 33 of Set 5 | puro
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 5 | hualmay
# Processing Record 38 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 5 | illela
# Processing Record 40 of Set 5 | bandarbeyla
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | saint-joseph
# Processing Record 43 of Set 5 | thyboron
# Processing Record 44 of Set 5 | petropavlivka
# Processing Record 45 of Set 5 | troyes
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | general roca
# Processing Record 48 of Set 5 | caborca
# Processing Record 49 of Set 5 | mangai
# Processing Record 50 of Set 5 | diffa
# Processing Record 1 of Set 6 | the pas
# Processing Record 2 of Set 6 | morehead
# Processing Record 3 of Set 6 | tangshan
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | santa marta
# Processing Record 6 of Set 6 | lethem
# Processing Record 7 of Set 6 | oruro
# Processing Record 8 of Set 6 | paslek
# Processing Record 9 of Set 6 | andenes
# Processing Record 10 of Set 6 | imbituba
# Processing Record 11 of Set 6 | lokoja
# Processing Record 12 of Set 6 | kieta
# Processing Record 13 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 6 | jacqueville
# Processing Record 15 of Set 6 | sistranda
# Processing Record 16 of Set 6 | dunedin
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | povolzhskiy
# Processing Record 20 of Set 6 | dingle
# Processing Record 21 of Set 6 | muli
# Processing Record 22 of Set 6 | buraydah
# Processing Record 23 of Set 6 | faaborg
# Processing Record 24 of Set 6 | sawtell
# Processing Record 25 of Set 6 | shakhtinsk
# Processing Record 26 of Set 6 | dzilam gonzalez
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | bassano
# Processing Record 29 of Set 6 | cooma
# Processing Record 30 of Set 6 | novoselitskoye
# Processing Record 31 of Set 6 | barcelona
# Processing Record 32 of Set 6 | hostotipaquillo
# Processing Record 33 of Set 6 | kungsbacka
# Processing Record 34 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 6 | abancay
# Processing Record 36 of Set 6 | yarada
# Processing Record 37 of Set 6 | seoul
# Processing Record 38 of Set 6 | kefamenanu
# Processing Record 39 of Set 6 | gambo
# Processing Record 40 of Set 6 | poronaysk
# Processing Record 41 of Set 6 | rosarito
# Processing Record 42 of Set 6 | finnsnes
# Processing Record 43 of Set 6 | mutare
# Processing Record 44 of Set 6 | burica
# City not found. Skipping...
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | kharan
# Processing Record 47 of Set 6 | maues
# Processing Record 48 of Set 6 | teguise
# Processing Record 49 of Set 6 | ambulu
# Processing Record 50 of Set 6 | ancona
# Processing Record 1 of Set 7 | nampula
# Processing Record 2 of Set 7 | chauk
# Processing Record 3 of Set 7 | kanniyakumari
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | comodoro rivadavia
# Processing Record 6 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 7 of Set 7 | arlit
# Processing Record 8 of Set 7 | panguna
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | jumla
# Processing Record 11 of Set 7 | seymchan
# Processing Record 12 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | ibatiba
# Processing Record 15 of Set 7 | makubetsu
# Processing Record 16 of Set 7 | wajir
# Processing Record 17 of Set 7 | pacific grove
# Processing Record 18 of Set 7 | kangaba
# Processing Record 19 of Set 7 | luwuk
# Processing Record 20 of Set 7 | nishihara
# Processing Record 21 of Set 7 | henties bay
# Processing Record 22 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | boende
# Processing Record 25 of Set 7 | tevaitoa
# Processing Record 26 of Set 7 | waingapu
# Processing Record 27 of Set 7 | panthersville
# Processing Record 28 of Set 7 | victoria
# Processing Record 29 of Set 7 | vikhorevka
# Processing Record 30 of Set 7 | barbastro
# Processing Record 31 of Set 7 | marsh harbour
# Processing Record 32 of Set 7 | zhangye
# Processing Record 33 of Set 7 | shache
# Processing Record 34 of Set 7 | talara
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | rudnogorsk
# Processing Record 37 of Set 7 | kimbe
# Processing Record 38 of Set 7 | toora-khem
# Processing Record 39 of Set 7 | sao miguel do araguaia
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | nador
# Processing Record 42 of Set 7 | quatre cocos
# Processing Record 43 of Set 7 | igrim
# Processing Record 44 of Set 7 | riverton
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | aklavik
# Processing Record 48 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | saint-michel-des-saints
# Processing Record 1 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 8 | chuy
# Processing Record 3 of Set 8 | erdemli
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | itoman
# Processing Record 6 of Set 8 | cheney
# Processing Record 7 of Set 8 | guiratinga
# Processing Record 8 of Set 8 | janossomorja
# Processing Record 9 of Set 8 | maceio
# Processing Record 10 of Set 8 | vitorino freire
# Processing Record 11 of Set 8 | lumding
# Processing Record 12 of Set 8 | sergeyevka
# Processing Record 13 of Set 8 | auki
# Processing Record 14 of Set 8 | chute-aux-outardes
# Processing Record 15 of Set 8 | lodja
# Processing Record 16 of Set 8 | grand gaube
# Processing Record 17 of Set 8 | altay
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | wewak
# Processing Record 20 of Set 8 | kanbe
# Processing Record 21 of Set 8 | terrace bay
# Processing Record 22 of Set 8 | quang ngai
# Processing Record 23 of Set 8 | guaranesia
# Processing Record 24 of Set 8 | mariinsk
# Processing Record 25 of Set 8 | la rochelle
# Processing Record 26 of Set 8 | abalak
# Processing Record 27 of Set 8 | carnarvon
# Processing Record 28 of Set 8 | jatiroto
# Processing Record 29 of Set 8 | manaus
# Processing Record 30 of Set 8 | ekhabi
# Processing Record 31 of Set 8 | berlevag
# Processing Record 32 of Set 8 | windhoek
# Processing Record 33 of Set 8 | clara
# Processing Record 34 of Set 8 | gorontalo
# Processing Record 35 of Set 8 | ahipara
# Processing Record 36 of Set 8 | lokomotivnyy
# Processing Record 37 of Set 8 | novomichurinsk
# Processing Record 38 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 8 | uribia
# Processing Record 40 of Set 8 | alexandria
# Processing Record 41 of Set 8 | mirabad
# Processing Record 42 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | dalby
# Processing Record 44 of Set 8 | komagane
# Processing Record 45 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | storsteinnes
# Processing Record 49 of Set 8 | kharp
# Processing Record 50 of Set 8 | birin
# Processing Record 1 of Set 9 | belaya gora
# Processing Record 2 of Set 9 | yar-sale
# Processing Record 3 of Set 9 | votice
# Processing Record 4 of Set 9 | poroshkovo
# Processing Record 5 of Set 9 | krasnogorsk
# Processing Record 6 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 9 | do gonbadan
# Processing Record 8 of Set 9 | absam
# Processing Record 9 of Set 9 | sabibah
# City not found. Skipping...
# Processing Record 10 of Set 9 | antalaha
# Processing Record 11 of Set 9 | provideniya
# Processing Record 12 of Set 9 | axim
# Processing Record 13 of Set 9 | pasni
# Processing Record 14 of Set 9 | byron bay
# Processing Record 15 of Set 9 | taltal
# Processing Record 16 of Set 9 | bathsheba
# Processing Record 17 of Set 9 | mnogovershinnyy
# Processing Record 18 of Set 9 | balikpapan
# Processing Record 19 of Set 9 | karcsa
# Processing Record 20 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 21 of Set 9 | manado
# Processing Record 22 of Set 9 | margate
# Processing Record 23 of Set 9 | boyuibe
# Processing Record 24 of Set 9 | pita
# Processing Record 25 of Set 9 | jiangdu
# Processing Record 26 of Set 9 | lagdo
# Processing Record 27 of Set 9 | kendari
# Processing Record 28 of Set 9 | chicama
# Processing Record 29 of Set 9 | sherman
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | tukrah
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | katha
# City not found. Skipping...
# Processing Record 34 of Set 9 | san angelo
# Processing Record 35 of Set 9 | lima
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | salinopolis
# Processing Record 39 of Set 9 | kalaleh
# Processing Record 40 of Set 9 | ust-omchug
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | ilulissat
# Processing Record 43 of Set 9 | zyryanka
# Processing Record 44 of Set 9 | gladstone
# Processing Record 45 of Set 9 | redmond
# Processing Record 46 of Set 9 | ponta do sol
# Processing Record 47 of Set 9 | reconquista
# Processing Record 48 of Set 9 | shieli
# Processing Record 49 of Set 9 | praya
# Processing Record 50 of Set 9 | atasu
# Processing Record 1 of Set 10 | namibe
# Processing Record 2 of Set 10 | harper
# Processing Record 3 of Set 10 | caravelas
# Processing Record 4 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | kenora
# Processing Record 7 of Set 10 | kisangani
# Processing Record 8 of Set 10 | nizhniy kuranakh
# Processing Record 9 of Set 10 | grand-santi
# Processing Record 10 of Set 10 | santa lucia
# Processing Record 11 of Set 10 | hamilton
# Processing Record 12 of Set 10 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | indramayu
# Processing Record 14 of Set 10 | rorvik
# Processing Record 15 of Set 10 | mezen
# Processing Record 16 of Set 10 | havelock
# Processing Record 17 of Set 10 | vanimo
# Processing Record 18 of Set 10 | batagay-alyta
# Processing Record 19 of Set 10 | can tho
# Processing Record 20 of Set 10 | mangla
# Processing Record 21 of Set 10 | podares
# Processing Record 22 of Set 10 | tuskegee
# Processing Record 23 of Set 10 | bongor
# Processing Record 24 of Set 10 | rantepao
# Processing Record 25 of Set 10 | beringovskiy
# Processing Record 26 of Set 10 | pechenga
# Processing Record 27 of Set 10 | chapais
# Processing Record 28 of Set 10 | natalio
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | kamenka
# Processing Record 31 of Set 10 | kuliyapitiya
# Processing Record 32 of Set 10 | borgarnes
# Processing Record 33 of Set 10 | neijiang
# Processing Record 34 of Set 10 | belmonte
# Processing Record 35 of Set 10 | kuching
# Processing Record 36 of Set 10 | vaovai
# City not found. Skipping...
# Processing Record 37 of Set 10 | uzice
# Processing Record 38 of Set 10 | vestmanna
# Processing Record 39 of Set 10 | chatellerault
# Processing Record 40 of Set 10 | kangaatsiaq
# Processing Record 41 of Set 10 | ponca city
# Processing Record 42 of Set 10 | isangel
# Processing Record 43 of Set 10 | el alto
# Processing Record 44 of Set 10 | lisala
# Processing Record 45 of Set 10 | katsuura
# Processing Record 46 of Set 10 | larsnes
# Processing Record 47 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 10 | fairbanks
# Processing Record 49 of Set 10 | staunton
# Processing Record 50 of Set 10 | japura
# Processing Record 1 of Set 11 | shakhovskaya
# Processing Record 2 of Set 11 | les cayes
# Processing Record 3 of Set 11 | snasa
# Processing Record 4 of Set 11 | santa cruz de la palma
# Processing Record 5 of Set 11 | magaria
# Processing Record 6 of Set 11 | eirunepe
# Processing Record 7 of Set 11 | lokachi
# Processing Record 8 of Set 11 | waddan
# Processing Record 9 of Set 11 | livingston
# Processing Record 10 of Set 11 | vestmannaeyjar
# Processing Record 11 of Set 11 | karratha
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | nankana sahib
# Processing Record 14 of Set 11 | mount gambier
# Processing Record 15 of Set 11 | burnie
# Processing Record 16 of Set 11 | maumere
# Processing Record 17 of Set 11 | shinpokh
# Processing Record 18 of Set 11 | santa barbara
# Processing Record 19 of Set 11 | novodolinskiy
# Processing Record 20 of Set 11 | north bend
# Processing Record 21 of Set 11 | brokopondo
# Processing Record 22 of Set 11 | labuan
# Processing Record 23 of Set 11 | gat
# Processing Record 24 of Set 11 | umm lajj
# Processing Record 25 of Set 11 | deputatskiy
# Processing Record 26 of Set 11 | black river
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | batemans bay
# Processing Record 31 of Set 11 | semporna
# Processing Record 32 of Set 11 | pozo colorado
# Processing Record 33 of Set 11 | myrtle beach
# Processing Record 34 of Set 11 | longonjo
# Processing Record 35 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 11 | katangli
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | ibicui
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | muzhi
# Processing Record 41 of Set 11 | arman
# Processing Record 42 of Set 11 | cerro de pasco
# Processing Record 43 of Set 11 | peniche
# Processing Record 44 of Set 11 | salalah
# Processing Record 45 of Set 11 | oshakati
# Processing Record 46 of Set 11 | saint-leu
# Processing Record 47 of Set 11 | wamba
# Processing Record 48 of Set 11 | trebechovice pod orebem
# Processing Record 49 of Set 11 | waipawa
# Processing Record 50 of Set 11 | uruzgan
# Processing Record 1 of Set 12 | san fernando
# Processing Record 2 of Set 12 | pangnirtung
# Processing Record 3 of Set 12 | chester
# Processing Record 4 of Set 12 | asau
# Processing Record 5 of Set 12 | ocher
# Processing Record 6 of Set 12 | haines junction
# Processing Record 7 of Set 12 | nusaybin
# Processing Record 8 of Set 12 | nizhniy ufaley
# Processing Record 9 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 12 | alice
# Processing Record 11 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 12 | korla
# Processing Record 13 of Set 12 | braslav
# City not found. Skipping...
# Processing Record 14 of Set 12 | eyrarbakki
# Processing Record 15 of Set 12 | juegang
# Processing Record 16 of Set 12 | pastavy
# Processing Record 17 of Set 12 | wuwei
# Processing Record 18 of Set 12 | likasi
# Processing Record 19 of Set 12 | kishi
# Processing Record 20 of Set 12 | krasnomayskiy
# Processing Record 21 of Set 12 | san rafael
# Processing Record 22 of Set 12 | filadelfia
# Processing Record 23 of Set 12 | almaznyy
# Processing Record 24 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 25 of Set 12 | krasnoselkup
# Processing Record 26 of Set 12 | sterling
# Processing Record 27 of Set 12 | xinye
# Processing Record 28 of Set 12 | zhengjiatun
# Processing Record 29 of Set 12 | jena
# Processing Record 30 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 12 | mutis
# Processing Record 32 of Set 12 | lingsugur
# Processing Record 33 of Set 12 | marzuq
# Processing Record 34 of Set 12 | alta floresta
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | aripuana
# Processing Record 37 of Set 12 | north branch
# Processing Record 38 of Set 12 | areka
# Processing Record 39 of Set 12 | jalu
# Processing Record 40 of Set 12 | salym
# Processing Record 41 of Set 12 | buala
# Processing Record 42 of Set 12 | ciudad bolivar
# Processing Record 43 of Set 12 | klaksvik
# Processing Record 44 of Set 12 | bonthe
# Processing Record 45 of Set 12 | mawlaik
# Processing Record 46 of Set 12 | ishigaki
# Processing Record 47 of Set 12 | shirokiy
# Processing Record 48 of Set 12 | nantucket
# Processing Record 49 of Set 12 | garowe
# Processing Record 50 of Set 12 | pochutla
# Processing Record 1 of Set 13 | potzu
# City not found. Skipping...
# Processing Record 2 of Set 13 | abu zabad
# Processing Record 3 of Set 13 | placerville
# Processing Record 4 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 13 | hurghada
# Processing Record 6 of Set 13 | adre
# Processing Record 7 of Set 13 | viernheim
# Processing Record 8 of Set 13 | takoradi
# Processing Record 9 of Set 13 | ballina
# Processing Record 10 of Set 13 | yakeshi
# Processing Record 11 of Set 13 | mayumba
# Processing Record 12 of Set 13 | kolda
# Processing Record 13 of Set 13 | nasriganj
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | nivala
# Processing Record 16 of Set 13 | beloha
# Processing Record 17 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 18 of Set 13 | rio grande
# Processing Record 19 of Set 13 | colac
# Processing Record 20 of Set 13 | meadow lake
# Processing Record 21 of Set 13 | tatawin
# Processing Record 22 of Set 13 | krasnyye tkachi
# Processing Record 23 of Set 13 | las matas de farfan
# Processing Record 24 of Set 13 | zalantun
# Processing Record 25 of Set 13 | padang
# Processing Record 26 of Set 13 | yuncheng
# Processing Record 27 of Set 13 | lugovoy
# Processing Record 28 of Set 13 | tagusao
# Processing Record 29 of Set 13 | the valley
# Processing Record 30 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 13 | turayf
# Processing Record 32 of Set 13 | synya
# Processing Record 33 of Set 13 | bumba
# Processing Record 34 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 13 | nava
# Processing Record 36 of Set 13 | coihaique
# Processing Record 37 of Set 13 | amga
# Processing Record 38 of Set 13 | ketchikan
# Processing Record 39 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 13 | boden
# Processing Record 41 of Set 13 | birobidzhan
# Processing Record 42 of Set 13 | virginia beach
# Processing Record 43 of Set 13 | faya
# Processing Record 44 of Set 13 | dombarovskiy
# Processing Record 45 of Set 13 | damnagar
# Processing Record 46 of Set 13 | nikolsk
# Processing Record 47 of Set 13 | powell river
# Processing Record 48 of Set 13 | khorixas
# Processing Record 49 of Set 13 | porto walter
# Processing Record 50 of Set 13 | opuwo
# Processing Record 1 of Set 14 | makakilo city
# Processing Record 2 of Set 14 | guerrero negro
# Processing Record 3 of Set 14 | coruripe
# Processing Record 4 of Set 14 | port blair
# Processing Record 5 of Set 14 | sukhumi
# Processing Record 6 of Set 14 | santa luzia
# Processing Record 7 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 14 | alekseyevka
# Processing Record 9 of Set 14 | tungor
# Processing Record 10 of Set 14 | orange
# Processing Record 11 of Set 14 | hirara
# Processing Record 12 of Set 14 | kawalu
# Processing Record 13 of Set 14 | alice town
# Processing Record 14 of Set 14 | raudeberg
# Processing Record 15 of Set 14 | troitsko-pechorsk
# Processing Record 16 of Set 14 | acapulco
# Processing Record 17 of Set 14 | storforshei
# Processing Record 18 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 19 of Set 14 | jubayl
# City not found. Skipping...
# Processing Record 20 of Set 14 | tondi
# Processing Record 21 of Set 14 | jizan
# Processing Record 22 of Set 14 | owo
# Processing Record 23 of Set 14 | corn island
# Processing Record 24 of Set 14 | vao
# Processing Record 25 of Set 14 | mantua
# Processing Record 26 of Set 14 | palmer
# Processing Record 27 of Set 14 | cairns
# Processing Record 28 of Set 14 | hami
# Processing Record 29 of Set 14 | port shepstone
# Processing Record 30 of Set 14 | santa cruz
# Processing Record 31 of Set 14 | kurumkan
# Processing Record 32 of Set 14 | ostroh
# Processing Record 33 of Set 14 | socorro
# Processing Record 34 of Set 14 | jidong
# Processing Record 35 of Set 14 | bayeux
# Processing Record 36 of Set 14 | lebork
# Processing Record 37 of Set 14 | gondanglegi
# Processing Record 38 of Set 14 | baracoa
# Processing Record 39 of Set 14 | immokalee
# Processing Record 40 of Set 14 | popondetta
# Processing Record 41 of Set 14 | alihe
# Processing Record 42 of Set 14 | stephenville crossing
# Processing Record 43 of Set 14 | sovetskiy
# Processing Record 44 of Set 14 | nakamura
# Processing Record 45 of Set 14 | cumberland
# Processing Record 46 of Set 14 | havoysund
# Processing Record 47 of Set 14 | champerico
# Processing Record 48 of Set 14 | omsukchan
# Processing Record 49 of Set 14 | vidalia
# Processing Record 50 of Set 14 | mehnagar
# Processing Record 1 of Set 15 | iracoubo
# Processing Record 2 of Set 15 | palembang
# Processing Record 3 of Set 15 | vieques
# Processing Record 4 of Set 15 | biltine
# Processing Record 5 of Set 15 | isla vista
# Processing Record 6 of Set 15 | daru
# Processing Record 7 of Set 15 | aksarka
# Processing Record 8 of Set 15 | shitanjing
# Processing Record 9 of Set 15 | coron
# Processing Record 10 of Set 15 | newport
# Processing Record 11 of Set 15 | kununurra
# Processing Record 12 of Set 15 | yatou
# Processing Record 13 of Set 15 | bologoye
# Processing Record 14 of Set 15 | cascais
# Processing Record 15 of Set 15 | sembakung
# Processing Record 16 of Set 15 | bulungu
# Processing Record 17 of Set 15 | biak
# Processing Record 18 of Set 15 | esil
# Processing Record 19 of Set 15 | slonim
# Processing Record 20 of Set 15 | ystad
# Processing Record 21 of Set 15 | san nicolas
# Processing Record 22 of Set 15 | ixtapa
# Processing Record 23 of Set 15 | sayyan
# Processing Record 24 of Set 15 | lufilufi
# Processing Record 25 of Set 15 | vila franca do campo
# Processing Record 26 of Set 15 | pereira barreto
# Processing Record 27 of Set 15 | saint-paul
# Processing Record 28 of Set 15 | gomel
# Processing Record 29 of Set 15 | douglas
# Processing Record 30 of Set 15 | kroya
# Processing Record 31 of Set 15 | ljungby
# Processing Record 32 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 33 of Set 15 | arawa
# Processing Record 34 of Set 15 | puerto carreno
# Processing Record 35 of Set 15 | ruidoso
# Processing Record 36 of Set 15 | plettenberg bay
# Processing Record 37 of Set 15 | laibin
# Processing Record 38 of Set 15 | upata
# Processing Record 39 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 15 | baixo guandu
# Processing Record 41 of Set 15 | laje
# Processing Record 42 of Set 15 | ponta delgada
# Processing Record 43 of Set 15 | nokaneng
# Processing Record 44 of Set 15 | mizdah
# Processing Record 45 of Set 15 | saint-georges
# Processing Record 46 of Set 15 | cienfuegos
# Processing Record 47 of Set 15 | leh
# Processing Record 48 of Set 15 | vilyuysk
# Processing Record 49 of Set 15 | kitimat
# Processing Record 50 of Set 15 | teguldet
# Processing Record 1 of Set 16 | todos santos
# Processing Record 2 of Set 16 | lowestoft
# Processing Record 3 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 16 | alyangula
# Processing Record 5 of Set 16 | mecca
# Processing Record 6 of Set 16 | devaprayag
# Processing Record 7 of Set 16 | smolenka
# Processing Record 8 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 16 | panjab
# Processing Record 10 of Set 16 | mo i rana
# Processing Record 11 of Set 16 | inhambane
# Processing Record 12 of Set 16 | mayo
# Processing Record 13 of Set 16 | yaan
# Processing Record 14 of Set 16 | springdale
# Processing Record 15 of Set 16 | agramonte
# Processing Record 16 of Set 16 | ust-kuyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Xiaoweizhai  26.1903  107.5125     71.71        75           2        3.53
# 1        Pevek  69.7008  170.3133     35.04        81         100       19.08
# 2       Castro -24.7911  -50.0119     51.66        82           0        1.57
# 3    Hay River  60.8156 -115.7999     82.45        33           0        5.55
# 4         Poum -20.2333  164.0167     68.40        64           9        9.33
#
#   Country Current Description
# 0      CN           clear sky
# 1      RU     overcast clouds
# 2      BR           clear sky
# 3      CA           clear sky
# 4      NC           clear sky

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df["Lat"] = city_data_df["Lat"].map("{:,.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:,.2f}".format)
city_data_df.head(10)
# Out:
#           City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Xiaoweizhai      CN   26.19   107.51     71.71        75           2
# 1        Pevek      RU   69.70   170.31     35.04        81         100
# 2       Castro      BR  -24.79   -50.01     51.66        82           0
# 3    Hay River      CA   60.82  -115.80     82.45        33           0
# 4         Poum      NC  -20.23   164.02     68.40        64           9
# 5      Merauke      ID   -8.47   140.33     74.07        80          61
# 6     Cherskiy      RU   68.75   161.30     42.42        57          89
# 7    Jamestown      US   42.10   -79.24     71.29        45          20
# 8       Aranos      NA  -24.13    19.12     56.01        28           0
# 9        Bluff      NZ  -46.60   168.33     44.80        68          93
#
#    Wind Speed Current Description
# 0        3.53           clear sky
# 1       19.08     overcast clouds
# 2        1.57           clear sky
# 3        5.55           clear sky
# 4        9.33           clear sky
# 5       11.32       broken clouds
# 6       15.93     overcast clouds
# 7        5.75          few clouds
# 8       12.08           clear sky
# 9        9.13     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
